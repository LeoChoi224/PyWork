# %%
print("오늘도 희준한 하루.")
# Out:
# 오늘도 희준한 하루.

# %%
'희준'
# Out:
# '희준'

# %% [markdown]
# # 큰 제목
# ## 오늘은 어떻게 조퇴하지?
#   - 메테오를 소환한다

# %%
'정준'
# Out:
# '정준'

# %%
with open("희준.txt", "w") as f:
  f.write("집에 가고 싶어잉")

# %%
base_path = r'/content/drive/MyDrive/KDT-2604/'

# %%
import os

# %%
with open(os.path.join(base_path, '최홍묵.txt'), 'w') as f:
  f.write("수업하기 싫다아~")

# %% [markdown]
# # 최최홍홍묵
