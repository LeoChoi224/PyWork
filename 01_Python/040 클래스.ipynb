# %% [markdown]
# # 클래스 (Class)

# %%
# 지금까지의 프로그래밍은 '함수 중심' (aka 명령중심, 절차중심)

# ex) 아래와 같이 goto() 함수 안에 필요한 인자를 넘겨준다

# goto("이길자", "집(논현동 188)")
# goto("김해성", "집(서초동 333)")
# 함수 중심이라는 것은 곧 '동작' 중심이라는 거다.
# 그러나 이는 '실세계'를 표현하는데는 한계가 있다.


# 사람이 인지하는 세상은 '객체 중심' 이기 때문이다

# '객체 중심' 프로그래밍은 다음과 같다.

# 예시]
# Person 클래스(class) 안에 다음의 '틀' 을 정의
#     - 이름 : 이름 정보 담는 '속성'
#     - 집주소 : 주소 정보 담는 '속성'
#     - goHome() : 집으로 가는 '동작' 수행

# 사람객체(object)들 생성
# lee = Person("이길자", "논현동 188") <- 이름, 집주소 등에 대한 정보가 객체에 담김
# kim = Person("김해성", "서초동 333") <- 이름, 집수소 등에 대한 정보가 객체에 담김

# lee.goHome()
# kim.goHome()

# 프로그래밍의 중심이 '함수' 중심이 아니라, 각각의 객체 중심( lee, kim )..


# 객체는 클래스로 정의를 하고
# 클래스를 통하여 객체를 생성한다   생성된 객체를 인스턴스(instance) 라 한다

# 흔히 클래스(Class ) 를 '붕어빵 틀'이라 하고
# 객체(object) 를 Class 로 찍어낸 '붕어빵'에 비유하곤 한다


# 파이썬에선 다음 순서대로 클래스를 사용한 객체중심 프로그래밍을 한다
#     ① 클래스 정의, class 키워드 사용
#     ② 객체 생성 (생성자 사용),생성된 객체를 '인스턴스(instance)' 라 한다 
#     ③ 객체 사용 (객체의 변수, 메소드)

# 클래스 이름은 
# 변수나 함수 이름 정의하는 규칙과 거의 동일하나
# 관례적으로 첫글자는 대문자로 한다

# %%
# 클래스 정의, 붕어빵 틀, 새로운 type 정의
class Cookie:
    pass

# %%
# 객체 (인스턴스) 생선. 붕어빵 찍어내기
a = Cookie() # Cookie 객체 생성
b = Cookie()
c = Cookie()

print(type(a))
print(type(b))
print(type(c))
# Out:
# <class '__main__.Cookie'>
# <class '__main__.Cookie'>
# <class '__main__.Cookie'>

# %%
type(a) is Cookie # a 는 Cookie 타입
# Out:
# True

# %%
a == b # 동등성 비교, False
# Out:
# False

# %%
a is b # 동일성 비교, False, 타입만 같을 뿐 다른 인스턴스다!
# Out:
# False

# %%
# 클래스를 통해 만들어진 객체를 인스턴스(instance)라고도 한다
# 객체와 인스턴스는 다소 혼용되어 표현되기도 한다.
# "a 는 Cookie 의 객체" 다
# "a 는 Cookie 의 인스턴스" 다

#----------------------------------------------------------------

# 객체의 '속성' --> 객체변수로 정의
# 객체의 '동작' --> 객체함수(메소드)로 정의

# 클래스 가 가져야 하는 변수를 '객체변수(instance variable)', 
# 혹은 속성값 (attribute value) 혹은 멤버변수(member variable) 혹은 필드(field) 라고도 함.
# 어떠한 메소드에서도 self. 키워드를 사용하여 정의 가능하고
# 인스턴스를 통해 생성도 가능.

# 객체변수 사용구문   . 사용
#   객체.객체변수

# 생성자 (Constructor)  __init__()
# 객체가 생성될때 '자동'으로 호출되는 특별한 메소드
# 주로 객체변수를 정의하고 초기화 하는 역할 수행

# 클래스 안에서 정의된 함수를 메소드(method) 라 함
# 메소드 호출 구문    . 사용
#    객체.메소드()
# 메소드가 호출될때는 해당 '객체' 에 대해서 동작하게 됨

# 모든 메소드는 기본적으로 첫번째 매개변수가 self 이다.

# %% [markdown]
# ## 객체변수, 생성자

# %%
# 사각형 이란 객체에 대해 설계해보자.
# 사각형 클래스를 정의해보자.

# 사각형의 속성은? -->  가로(width),  세로(height)
# 사각형의 동작은? --> ??

# Rectangle 객체 정의 (클래스 정의,  붕어빵틀 제작)
class Rectangle:

    # 생성자 함수
    def __init__(self):
        print('Rectangle() 생성자 호출')
        # 객체변수들 (속성)
        self.width = 0   # 객체변수 width 선언, 0 으로 초기화
        self.height = 0  # 객체변수 height 선언, 0 으로 초기화


r1 = Rectangle()
# Out:
# Rectangle() 생성자 호출

# %%
r1.width
# Out:
# 0

# %%
r1.height
# Out:
# 0

# %%
# r1.aaa

# %%
r2 = Rectangle()

r2.width, r2.height
# Out:
# Rectangle() 생성자 호출
# (0, 0)

# %%
r1.width, r1.height = 100, 200
r2.width, r2.height = 50, 30

print(r1.width, r1.height)
print(r2.width, r2.height)

# width, height 객체변수는 각 인스턴스별로 '각각' 가지고 있다!
# Out:
# 100 200
# 50 30

# %%
r1.area = 19  # r1 객체에 area 객체변수 추가.  (임의 추가 가능!)
r1.area
# Out:
# 19

# %% [markdown]
# ## 메소드 (method)

# %%
#------------------------------------------
# 사각형의 동작? ----> 객체 메소드(함수)로 정의
#   - 사각형의 넓이를 구하기
#   - 사각형의 둘레를 구하기 

class Rectangle:
    def __init__(self):  
        print("Rectangle() 생성자 호출")
        self.width = 0
        self.height = 0

    # 넓이 구하기
    def get_area(self):
        area = self.width * self.height
        return area

    # 둘레 구하기
    def get_perimeter(self):
        return (self.width + self.height) * 2

r1 = Rectangle()
r2 = Rectangle()
# Out:
# Rectangle() 생성자 호출
# Rectangle() 생성자 호출

# %%
r1.height, r1.width = 10, 20

# %%
r1.get_area()
# Out:
# 200

# %%
r1.get_perimeter()
# Out:
# 60

# %%
r2.get_area(), r2.get_perimeter()
# Out:
# (0, 0)

# %%
# r1.get_area(100)

# %% [markdown]
# ## 메소드 첫번째 매개 변수 Self

# %%
r3 = Rectangle()
r3.width, r3.heigth = 10, 20
# Out:
# Rectangle() 생성자 호출

# %%
r3.get_area()
# Out:
# 0

# %%
Rectangle.get_area(r3)
# Out:
# 0

# %%
Rectangle.get_area
# Out:
# <function __main__.Rectangle.get_area(self)>

# %%
# Rectangle.width

# %%
str1 = "희준정준"

str1.replace('준', '군')
# Out:
# '희군정군'

# %%
str.replace(str1, '준', '군')
# Out:
# '희군정군'

# %%
my_str = "123,456원"
list(filter(str.isdigit, my_str))
# Out:
# ['1', '2', '3', '4', '5', '6']

# %% [markdown]
# # 생성자 매개변수

# %%
class Rectangle:
    # def __init__(self, width, height):  
    def __init__(self, width=0, height=0):          
        print(f"Rectangle(width={width}, height={height}) 생성자 호출")
        self.width = width  # 생성자 매개변수로 객체변수 초기화
        self.height = height

    # 넓이 구하기
    def get_area(self):
        area = self.width * self.height
        return area

    # 둘레 구하기
    def get_perimeter(self):
        return (self.width + self.height) * 2

r1 = Rectangle()  # 에러
r2 = Rectangle(30, 20)
# Out:
# Rectangle(width=0, height=0) 생성자 호출
# Rectangle(width=30, height=20) 생성자 호출

# %%
r1.get_area()
# Out:
# 0

# %%
r3 = Rectangle(width=33, height=44)
# Out:
# Rectangle(width=33, height=44) 생성자 호출

# %%
r4 = Rectangle(**{'width': 33, 'height': 44})
# Out:
# Rectangle(width=33, height=44) 생성자 호출

# %% [markdown]
# # 객체 생성 연습: Circle

# %%
# 연습 : 원에 대한 객체 정의

#  클래스 정의 Circle
#  객체변수는 반지름  (radius)

#  생성자 함수. (매개변수 받는 생성자)
#  원의 면적을 리턴하는 메소드 get_area()
#  원의 둘레 계산하여 리턴하는 메소드  get_perimeter()
#  반지름을 x n 배로 만들어 주는 multiple_radius(n)

class Circle:
    def __init__(self, radius):
        self.radius = radius

    def get_area(self):
        return self.radius * 3.14 * 2

    def get_perimeter(self):
        return (self.radius ** 2) * 3.14

    def multiple_radius(self, n):
        radius = self.radius * n
        return radius
        
    
r1 = Circle(4)
r2 = Circle(3)

# %%
r1.get_area()
# Out:
# 25.12

# %%
r1.get_perimeter()
# Out:
# 50.24

# %%
r1.multiple_radius(2)
# Out:
# 8

# %% [markdown]
# # 연습: Point2D
# 2차원 좌표 객체

# %%
#  클래스 정의 Point2D

#  객체변수는 x, y

#  생성자 : x, y 초기화

#  메소드
#    원점에서 부터 거리 계산 get_distance() -> float
#    두 점 사이의 거리 계산 get_distance_from(other:Point2D) -> float
import math 

class Point2D:
    def __init__(self, x = 0, y = 0):
        self.x = x
        self.y = y
    
    def get_distance(self):
        return math.sqrt((self.x ** 2) + (self.y ** 2))

    def get_distance_from(self, other):  # other:Point2D 사이의 거리 리턴
        return math.sqrt((self.x - other.x) ** 2 + (self.y - other.y) ** 2)

# %%
p1 = Point2D(1, 2)
p1.get_distance()
# Out:
# 2.23606797749979

# %%
p2 = Point2D(0, 2)

# %%
p3 = Point2D(0, -1)
p2.get_distance_from(p3)  # 3.0
# Out:
# 3.0

# %% [markdown]
# # id()
# 객체의 고유한 id (aka 메모리 주소)

# %%
p1 = Point2D(1, 2)
p2 = Point2D(1, 2)

# %%
id(p1), id(p2)  # 다른 객체다!
# Out:
# (4433688048, 4434782752)

# %%
p1 is p2
# Out:
# False

# %%
p1 == p2  # 동등성 여부는 __eq__ 를 정의 해줘야 한다.
# Out:
# False

# %% [markdown]
# # `__dict__` 속성

# %%
# 인스턴스의 __dict__ 속성

p1.__dict__ # dict 타입
# Out:
# {'x': 1, 'y': 2}

# %%
p2.__dict__
# Out:
# {'x': 1, 'y': 2}

# %%
# 클래스 의 __dict__ 속성
Point2D.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__init__': <function __main__.Point2D.__init__(self, x=0, y=0)>,
#               'get_distance': <function __main__.Point2D.get_distance(self)>,
#               'get_distance_from': <function __main__.Point2D.get_distance_from(self, other)>,
#               '__dict__': <attribute '__dict__' of 'Point2D' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Point2D' objects>,
#               '__doc__': None})

# %% [markdown]
# ## 속성 / 메소드 추가, 삭제 가능!

# %%
p1.color = "RED"

p1.__dict__
# Out:
# {'x': 1, 'y': 2, 'color': 'RED'}

# %%
p2.__dict__
# Out:
# {'x': 1, 'y': 2}

# %%
p2.get_distance()
# Out:
# 2.23606797749979

# %%
del(p2.y)

# %%
p2.get_distance()  # 헐~...  이제 y 속성이 없다..
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 p2.get_distance()  # 헐~...  이제 y 속성이 없다..
#
# Cell In[83], line 18, in Point2D.get_distance(self)
#      17     def get_distance(self):
# ---> 18         return math.sqrt((self.x ** 2) + (self.y ** 2))
#
# AttributeError: 'Point2D' object has no attribute 'y'
