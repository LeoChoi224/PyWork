# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
driver = webdriver.Chrome()

# %%
url = "https://itgn.maniaro.net/student/ver4/curri/lecture/index.php?Pcode=300005"

# %%
LOGIN_ID = "xxxxx"
LOGIN_PW = "zzzzz"

# %%
driver.get(url)

# %%
elements = driver.find_elements()
elements.send_keys(Keys.ENTER)
# Out:
# ---------------------------------------------------------------------------
# UnexpectedAlertPresentException           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 elements = driver.find_elements()
#       2 elements.send_keys(Keys.ENTER)
#
# File ~/LeoData/MyCode/KoreaITAcademy/LangChain/.venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:899, in WebDriver.find_elements(self, by, value)
#     895     return self.execute_script(find_element_js, by.to_dict())
#     897 # Return empty list if driver returns null
#     898 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 899 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File ~/LeoData/MyCode/KoreaITAcademy/LangChain/.venv/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:468, in WebDriver.execute(self, driver_command, params)
#     465 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     467 if response:
# --> 468     self.error_handler.check_response(response)
#     469     response["value"] = self._unwrap_value(response.get("value", None))
#     470     return response
#
# File ~/LeoData/MyCode/KoreaITAcademy/LangChain/.venv/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py:231, in ErrorHandler.check_response(self, response)
#     229     elif "alert" in value:
#     230         alert_text = value["alert"].get("text")
# --> 231     raise exception_class(message, screen, stacktrace, alert_text)
#     232 raise exception_class(message, screen, stacktrace)
#
# UnexpectedAlertPresentException: Alert Text: 세션이 만료되었거나 접근 권한이 없습니다.
# Message: unexpected alert open: {Alert text : 세션이 만료되었거나 접근 권한이 없습니다.}
#   (Session info: chrome=148.0.7778.216)
# Stacktrace:
# 0   chromedriver                        0x0000000102e1cc40 cxxbridge1$str$ptr + 3221216
# 1   chromedriver                        0x0000000102e14b1c cxxbridge1$str$ptr + 3188156
# 2   chromedriver                        0x00000001028d78f4 _RNvCsiKAbIcglKMQ_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 75152
# 3   chromedriver                        0x000000010295fe3c _RNvCsiKAbIcglKMQ_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 633560
# 4   chromedriver                        0x00000001029159c0 _RNvCsiKAbIcglKMQ_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 329308
# 5   chromedriver                        0x0000000102ddab70 cxxbridge1$str$ptr + 2950672
# 6   chromedriver                        0x0000000102dde2c8 cxxbridge1$str$ptr + 2964840
# 7   chromedriver                        0x0000000102dbf8a8 cxxbridge1$str$ptr + 2839368
# 8   chromedriver                        0x0000000102ddeb48 cxxbridge1$str$ptr + 2967016
# 9   chromedriver                        0x0000000102db03d4 cxxbridge1$str$ptr + 2776692
# 10  chromedriver                        0x0000000102e037ac cxxbridge1$str$ptr + 3117644
# 11  chromedriver                        0x0000000102e0390c cxxbridge1$str$ptr + 3117996
# 12  chromedriver                        0x0000000102e14774 cxxbridge1$str$ptr + 3187220
# 13  libsystem_pthread.dylib             0x000000018993dc58 _pthread_start + 136
# 14  libsystem_pthread.dylib             0x0000000189938c1c thread_start + 8

# %%
elements = driver.find_element(By.CSS_SELECTOR, "td[onclick*='/student']")
elements.click()
