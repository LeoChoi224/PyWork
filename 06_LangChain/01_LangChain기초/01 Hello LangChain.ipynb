# %% [markdown]
# # Hello LangChain

# %% [markdown]
# # 환경변수

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
print(f'{os.getenv('OPENAI_API_KEY')[:20]}...')
# Out:
# sk-proj-DPrT3N-1Ilp9...

# %% [markdown]
# # LangChain  관련 주요 링크
#
# > 아래 정보는 `2026.01 현재 LangChain v1.2.x` 의 정보입니다.
# > LangChain 은 매우 빠르게 업데이트 되는 프레임워크입니다. 수시로 변경될수 있으니 ChatGPT 등을 통한 정보보다 공식 문서와 교차검증을 꼭 해보시기 바랍니다.
#
# - LangChain Docs: https://docs.langchain.com/oss/python/langchain/overview
# - LangChain Reference: https://reference.langchain.com/python/langchain/langchain/
#
# - LangGraph Docs: https://docs.langchain.com/oss/python/langgraph/overview
# - LnagGraph Reference: https://reference.langchain.com/python/langgraph/
#
#
# ## Langchain 의 패키지 구성
#
#
# ### Base Packages
# - [langchain](https://reference.langchain.com/python/langchain/)
# - [langchain-core](https://reference.langchain.com/python/langchain_core/)
# - [langchain-text-splitters](https://reference.langchain.com/python/langchain_text_splitters/)
# - [langchain-mcp-adapers](https://reference.langchain.com/python/langchain_mcp_adapters/)
# - [langchain-tests](https://reference.langchain.com/python/langchain_tests/)
# - [langchain-classic](https://reference.langchain.com/python/langchain_classic/)  `2026.12 까지는 유지`
#
# ### Integrations
# - 랭체인은 수많은 LLM 모델들과 커뮤니티, 벡터스토어, 데이터베이스, 툴 들과 함께 사용할수 있도록 제공되는 패키지들이 많다 (앞으로 더 많아 질거다)
# - [LangChain integrations](https://reference.langchain.com/python/integrations/) ← 상당히 많은 패키지목록 확인가능
#
#     - [langchain-openai](https://reference.langchain.com/python/integrations/langchain_openai/)
#     - [langchain-huggingface](https://reference.langchain.com/python/integrations/langchain_huggingface/)
#     - [langchain-mistralai](https://reference.langchain.com/python/integrations/langchain_mistralai/)
#     - 그밖에도 많이 있다 ...

# %% [markdown]
# # 1. LLM  & Chat model
#
# LangChain 은 LLM 과 Chat model 두가지를 지원합니다
#
# `LLM`(Large Language Model)과 `Chat Model`은 비슷한 역할을 하지만, 약간의 차이점이 있습니다.
#
# 이는 주로 **모델의 입력 및 상호작용 방식**에서 나타난다.
#
# ---
#
# ### 1. LLM (Large Language Model)
# - **특징**:
#   - 일반적으로 **텍스트 입력**을 받고, 이에 대한 **텍스트 출력**을 생성합니다.
#   - 단순한 프롬프트 기반 입력/출력을 처리하기 위한 모델입니다.
#   - 사용자가 제공한 입력 텍스트를 분석하고, 그에 대한 결과를 한 번에 출력합니다.
# - **입력 형식**:
#   ```plaintext
#   "Tell me a summary of the benefits of LangChain."
#   ```
# - **출력 형식**:
#   ```plaintext
#   "LangChain is a framework designed to simplify the development of applications powered by large language models, making it easier to manage prompts, chains, and integrations."
#   ```
# - **주요 사용 사례**:
#   - 단일 질문-답변
#   - 텍스트 생성
#   - 간단한 프롬프트 처리를 위한 작업
#
# ---
#
# ### 2. Chat Model
# - **특징**:
#   - **대화 형식**으로 설계된 모델로, 다중 턴 대화를 처리할 수 있다.
#   - 입력 형식이 **메시지 Message**로 구성되며, 각 메시지는 사용자의 메시지 (User Message)와 시스템의 메시지(System Message)로 나뉜다.
#   - '문맥'을 이해하고 '대화의 흐름'을 유지하는 데 최적화되어 있다.
# - **입력 형식**:
#   메시지 객체를 전달해야 하며, 보통 아래와 같은 구조입니다.
#   ```python
#   [
#       {"role": "system", "content": "You are an assistant who helps with Python programming."},
#       {"role": "user", "content": "Can you explain the difference between LLM and chat models in LangChain?"}
#   ]
#   ```
# - **출력 형식**:
#   ```python
#   {"role": "assistant", "content": "Sure! LLM and Chat Models differ in their input and interaction styles..."}
#   ```
# - **주요 사용 사례**:
#   - 다중 턴 대화
#   - 문맥 추적 및 유지 (대화 히스토리 반영)
#   - 대화 기반 챗봇, FAQ 시스템 등
#
# ---
#
# ### 3. 주요 차이점 요약
# | **특징**        | **LLM**                                                | **Chat Model**                                        |
# |-----------------|------------------------------------------------------|----------------------------------------------------|
# | **입력 형식**   | 단일 텍스트 입력                                         | 역할 기반의 대화 메시지 객체 (role: system, user, assistant) |
# | **대화 히스토리**| 문맥 추적 불가능 (단일 요청 처리)                          | 대화 히스토리를 통해 문맥을 유지하고 반영                 |
# | **사용 목적**   | 텍스트 생성, 요약, 단순 질의응답                             | 대화형 인터페이스, 챗봇, 다중 턴 질의응답               |
# | **응용 사례**   | 단일 질문-답변, 텍스트 생성                                | 고객 지원 챗봇, 인터랙티브 Q&A, 멀티턴 대화 시스템          |
#
# ---
#
#
# ### 5. 언제 어떤 것을 선택해야 할까요?
# - **단일 작업이나 간단한 텍스트 생성**:
#   - `LLM`을 사용하는 것이 적합합니다.
# - **대화 기반 애플리케이션이나 문맥을 유지해야 하는 작업**:
#   - `Chat Model`을 사용하는 것이 더 적합합니다.

# %% [markdown]
# # LangChain 첫 호출

# %%
from langchain_openai import OpenAI  # LLM

# %%
from langchain_openai import ChatOpenAI  # chat Model

# %%
llm = OpenAI()  # OPENAI_API_KEY 환경변수 필요!

# %%
llm.model_name  # 디폴트 사용 모델
# Out:
# 'gpt-3.5-turbo-instruct'

# %%
chat = ChatOpenAI()
chat.model_name
# Out:
# 'gpt-3.5-turbo'

# %% [markdown]
# ## LLM 호출

# %%
llm.invoke("How many planets are there?")
# Out:
# '\n\nAs of 2021, there are eight known planets in our solar system: Mercury, Venus, Earth, Mars, Jupiter, Saturn, Uranus, and Neptune. Pluto was previously classified as a planet but is now considered a dwarf planet.'

# %%
result = llm.invoke("How many planets are there?")  # 결과 str
print('답변:', result)
# Out:
# 답변:
#
# As of September 2021, there are eight planets in our solar system: Mercury, Venus, Earth, Mars, Jupiter, Saturn, Uranus, and Neptune.

# %%
result = llm.invoke("태양계에는 얼마나 많은 행성들이 있죠?")  # 결과 str

print('답변:', result)
# Out:
# 답변:
#
# 태양계에는 8개의 행성이 있습니다. 이들은 수성, 금성, 지구, 화성, 목성, 토성, 천왕성, 해왕성입니다. 하지만 2006년에 명왕성은 소행성으로 재분류되었으므로 이제는 8개의 행성이 아니라 5개의 외계 행성으로 구분됩니다.

# %% [markdown]
# ## ChatModel 호출

# %%
result = chat.invoke("How many planets are there?")  # 문자열로 호출해도 UserMessage로 전달

print(type(result))  # Message
print('🐶', result)
print('🤖답변:', result.content)
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# 🐶 content='There are currently eight recognized planets in our solar system: Mercury, Venus, Earth, Mars, Jupiter, Saturn, Uranus, and Neptune.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 29, 'prompt_tokens': 13, 'total_tokens': 42, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DtNWfApfuawwvDO2pa5tYsdAOSwq2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019eece4-481a-7a00-a6af-a19f48fdb056-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 29, 'total_tokens': 42, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# 🤖답변: There are currently eight recognized planets in our solar system: Mercury, Venus, Earth, Mars, Jupiter, Saturn, Uranus, and Neptune.

# %%
from langchain_core.messages import HumanMessage

# %%
message = HumanMessage(content="How many planets are there?")
result = chat.invoke([message])  # List[Message]

print(type(result))  # Message
print('🐶', result)
print('🤖답변:', result.content)
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# 🐶 content='There are eight planets in our solar system: Mercury, Venus, Earth, Mars, Jupiter, Saturn, Uranus, and Neptune.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 13, 'total_tokens': 40, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DtNcAft1YnwmxhAkAZN6qTJnluLB8', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019eece9-7f35-7c90-98db-686b974537b5-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 27, 'total_tokens': 40, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# 🤖답변: There are eight planets in our solar system: Mercury, Venus, Earth, Mars, Jupiter, Saturn, Uranus, and Neptune.

# %%
result = chat.invoke([
    {"role": "human", "content": "How many planets are there?"}
])  

print(type(result))  # Message
print('💚', result)
print('💖답변:', result.content)
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# 💚 content='There are 8 planets in our solar system: Mercury, Venus, Earth, Mars, Jupiter, Saturn, Uranus, and Neptune.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 13, 'total_tokens': 41, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DtNkQbd1dcpAaYDPr63YrQDsgJdJC', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019eecf1-4ee4-71e3-a515-736f33c51cdc-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 28, 'total_tokens': 41, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# 💖답변: There are 8 planets in our solar system: Mercury, Venus, Earth, Mars, Jupiter, Saturn, Uranus, and Neptune.

# %% [markdown]
# ## 한글 or 영어 ?
#
# 챗 GPT의 언어 처리 능력은 인공지능 기술의 훌륭한 발전을 보여줍니다. 하지만 사용자가 받는 답변의 품질은 제출하는 언어에 따라 약간의 차이가 있을 수 있습니다. 이런 차이는 챗 GPT가 학습하는 과정에서 다양한 언어의 데이터 양과 품질, 그리고 언어별 특성을 얼마나 잘 처리하는지에 따라 결정됩니다.
#
# OpenAI의 언어 모델, 특히 GPT 시리즈는 다양한 데이터 소스에서 얻은 대량의 데이터로 학습됩니다. 이 데이터는 주로 영어를 비롯한 여러 언어에서 수집되며, 학습 데이터의 구성은 모델의 성능과 일반화 능력에 큰 영향을 미칩니다.
#
# 영어는 전세계적으로 많이 사용되며*, 인터넷 상의 데이터도 영어가 많아서 챗 GPT는 영어 질문에 대해 더 정확하고 자연스러운 답변을 제공할 확률이 높습니다. 그러나 한국어와 같은 다른 언어는 상대적으로 데이터가 부족하거나, 언어의 복잡성 때문에 처리가 더 어려울 수 있어, 이로 인해 답변의 품질에 차이가 나타날 수 있습니다.
#
# 참고
# - https://fastcampus.co.kr/gov_review_insightGPTlang

# %%
# 아래와 같이 api 키를 직접 매개변수로 건네줄수도 있지만...  KEY 비추한다.  환경변수 사용을 추천한다.
#
# llm = OpenAI(openai_api_key="sk-")
# chat = ChatOpenAI(openai_api_key="sk-")

# %%
from langchain_anthropic.chat_models import ChatAnthropic

# %% [markdown]
# # Invoke Message

# %%
# ChatModel 은 '질문'만 받는게 아니라 '대화' 를 나눌수 있다 (Message 를 보낼수도 있다)
# '대화(conversation)' 은
#    : 여러 메세지 묶음
#    : 상대의 대화의 맥락에 맞게 대답할수 있다.

# %%
# https://python.langchain.com/docs/integrations/chat/openai/#instantiation
# 레퍼런스 : https://python.langchain.com/api_reference/openai/chat_models/langchain_openai.chat_models.base.ChatOpenAI.html
"""
chat = ChatOpenAI(
    model="gpt-4o",
    temperature=0,
        # 모델의 응답 다양성을 제어하는 역할을 합니다.
        # 이는 OpenAI의 GPT 모델에서 사용하는 매개변수로,
        #  생성되는 텍스트의 창의성과 확률적 다양성(랜덤성을 조정합니다)ㄴ
        #
    max_tokens=None,  # model이 리턴하는 결과의 최대 token 개수지정.
    timeout=None,
    max_retries=2,
    # api_key="...",  # if you prefer to pass api key in directly instaed of using env vars
    # base_url="...",
    # organization="...",
    # other params...
)
"""
None

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
from langchain.messages import HumanMessage, SystemMessage, AIMessage

# HumanMessage : 사람이 AI 에 보내는 Message
# SystemMessage : LLM 에 설정들을 제공하기 위한 Message
# AIMessage: AI 에 의해 리턴되는 Message

# %%
# Message 들의 List
messages = [
    SystemMessage(
        content = "You are a geography expert. And your only reply in Korean",
    ),
    AIMessage(
        content = "안녕, 내 이름은 김정준 이야.",
    ),
    HumanMessage(
        content = """What is the distance between Mexico and Thailand.
          Also, what is your name?""",        
    )
]

# %%
result = chat.invoke(messages)
result
# Out:
# AIMessage(content='멕시코와 태국 사이의 거리는 약 16,000km입니다. 제 이름은 김정준입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 37, 'prompt_tokens': 61, 'total_tokens': 98, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DtO2aZblg7l7eui1ixHydbcvSRY0J', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019eed02-790e-76b3-9d90-5dacd430863a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 61, 'output_tokens': 37, 'total_tokens': 98, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
result.content
# Out:
# '멕시코와 태국 사이의 거리는 약 16,000km입니다. 제 이름은 김정준입니다.'

# %%
messages = [
    {"role": "system", "content": "You are a geography expert. And your only reply in Korean"},
    {"role": "ai", "content": "안녕, 내 이름은 김정준 이야."},
    {"role": "human", "content": """What is the distance between Mexico and Thailand.
          Also, what is your name?"""},
]

result = chat.invoke(messages)
result.content
# Out:
# '멕시코와 태국 사이의 거리는 대략 16,000km입니다. 제 이름은 김정준입니다.'

# %%
# list[tuple] 도 가능.
messages = [ 
    ("system", "You are a geography expert. And your only reply in Korean"),
    ("ai", "안녕, 내 이름은 김정준 이야."),
    ("human", """What is the distance between Mexico and Thailand.
          Also, what is your name?"""),
]

result = chat.invoke(messages)
result.content
# Out:
# '멕시코와 태국 사이의 거리는 약 16,000km입니다. 제 이름은 김정준입니다.'

# %% [markdown]
# # Prompt Template

# %% [markdown]
# ## Prompt
# ↑ messages 를 prompt 라고도 함 (?)
# - 모델에 입력으로 제공되는 텍스트나 데이터
# - 모델에게 작업을 수행하도록 지시하거나, 모델이 생성할 텍스트의 컨텍스트를 제공
# - LLM 과 의사소통하기 위한 방법
#
# ---
#
# LLM(대형 언어 모델)에서 **프롬프트 prompt**란 모델에 **입력**으로 제공되는 텍스트나 데이터입니다. 이는 모델에게 작업을 수행하도록 지시하거나, 모델이 생성할 텍스트의 컨텍스트를 제공합니다. 프롬프트는 모델의 출력을 결정하는 중요한 역할을 합니다.
#
# ### 프롬프트의 역할:
# 1. **모델에 대한 지시**: 프롬프트는 모델에게 무엇을 해야 할지 알려주는 역할을 합니다. 예를 들어, 사용자가 모델에게 질문을 하거나, 특정 스타일의 텍스트를 생성하도록 요청할 때 프롬프트가 필요합니다.
#
# 2. **컨텍스트 제공**: 모델이 적절한 응답을 생성할 수 있도록 필요한 배경 정보나 문맥을 제공합니다. 예를 들어, 어떤 주제에 대한 질문을 할 때, 관련 배경 정보를 제공하여 모델이 더 정확한 답을 할 수 있게 합니다.
#
# 3. **모델의 출력 유도**: 프롬프트가 모델의 출력을 유도하고, 생성되는 텍스트의 스타일, 내용, 형식 등을 결정하는 데 중요한 영향을 미칩니다.
#
# ### 예시:
# 1. **질문 응답**:
#    - **프롬프트**: "What is the capital of France?"
#    - **출력**: "The capital of France is Paris."
#
# 2. **창의적 글쓰기**:
#    - **프롬프트**: "Write a short story about a dragon and a knight."
#    - **출력**: 모델이 창의적으로 드래곤과 기사에 관한 이야기를 생성합니다.
#
# 3. **번역**:
#    - **프롬프트**: "Translate the following sentence to Spanish: 'Hello, how are you?'"
#    - **출력**: "Hola, ¿cómo estás?"
#
# ### 프롬프트의 종류:
# - **단순한 질문**: 사용자가 단순히 궁금한 점을 묻는 형태.
# - **지시문**: 특정 작업을 수행하도록 지시하는 형태.
# - **형식화된 입력**: 특정 형식이나 구조를 갖춘 입력(예: 텍스트 요약, 번역, 코드 작성 등).
#
# ### 프롬프트 설계의 중요성:
# - **정확한 결과**를 얻기 위해서는 **프롬프트의 설계**가 매우 중요합니다. 프롬프트가 모호하거나 불완전하면 모델이 원하는 출력을 생성하기 어렵습니다.
# - 다양한 프롬프트를 실험하면서 모델의 반응을 관찰하고, 가장 적합한 프롬프트를 찾는 것이 중요합니다.
#
# ### 프롬프트 설계 팁:
# 1. **명확하고 구체적인 지시**: 무엇을 원하는지 정확하게 전달하세요. 예를 들어, "Explain quantum mechanics"보다는 "Explain quantum mechanics in simple terms for a high school student"와 같이 구체적인 요구를 하는 것이 좋습니다.
#
# 2. **적절한 컨텍스트 제공**: 필요한 배경 정보나 문맥을 제공하면 모델이 더 정확한 답변을 생성할 수 있습니다.
#
# 3. **다양한 실험**: 프롬프트를 조금씩 바꿔가며 테스트해 보면서 최적의 응답을 유도할 수 있습니다.
#
# ### 결론:
# 프롬프트는 대형 언어 모델에게 작업을 지시하는 중요한 입력으로, 모델이 수행할 작업의 방향을 결정짓는 요소입니다. 프롬프트를 잘 설계하는 것이 LLM을 효과적으로 활용하는 데 큰 도움이 됩니다.

# %% [markdown]
# ## PromptTemplate

# %%
from langchain_core.prompts.prompt import PromptTemplate
from langchain_core.prompts.chat import ChatMessagePromptTemplate, ChatPromptTemplate

# %%
# ChatPromptTemplate 는 message(s) 로부터 template 을 만듬.
# PromptTemplate 는 string 을 이용해서 template 을 만듬.
#  ↑ 둘다 유용하게 쓰임.

# ChatMessagePromptTemplate <- 단일 Message 템플릿
# ChatPromptTemplate <- 여러 Message들의 모음(list) 템플릿

# %%
template = PromptTemplate.from_template(
    # placeholder {...} 사용 => input_variables
    "What is the distance between {country_a} and {country_b}"    
)

print(type(template))
template
# Out:
# <class 'langchain_core.prompts.prompt.PromptTemplate'>
# PromptTemplate(input_variables=['country_a', 'country_b'], input_types={}, partial_variables={}, template='What is the distance between {country_a} and {country_b}')

# %%
prompt = template.format(country_a="Canada", country_b="Japan")
prompt
# Out:
# 'What is the distance between Canada and Japan'

# %%
chat.invoke(prompt)
# Out:
# AIMessage(content='The distance between Canada and Japan is approximately 7,000 kilometers (4,350 miles) when measured in a straight line.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 15, 'total_tokens': 41, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DtOUA8ohDIsoJ7HqbwXInLwdbfvl5', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019eed1c-9481-7b22-a55d-11cef4496018-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 26, 'total_tokens': 41, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# prompt = template.format(country_a="Canada")  # KeyError: 'country_b'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 prompt = template.format(country_a="Canada")
#
# File ~/LeoData/MyCode/KoreaITAcademy/LangChain/Dropbox/K16/PyWork/.venv/lib/python3.12/site-packages/langchain_core/prompts/prompt.py:201, in PromptTemplate.format(self, **kwargs)
#     192 """Format the prompt with the inputs.
#     193
#     194 Args:
#    (...)    198     A formatted string.
#     199 """
#     200 kwargs = self._merge_partial_and_user_variables(**kwargs)
# --> 201 return DEFAULT_FORMATTER_MAPPING[self.template_format](self.template, **kwargs)
#
# File ~/.pyenv/versions/3.12.5/lib/python3.12/string.py:190, in Formatter.format(self, format_string, *args, **kwargs)
#     189 def format(self, format_string, /, *args, **kwargs):
# --> 190     return self.vformat(format_string, args, kwargs)
#
# File ~/LeoData/MyCode/KoreaITAcademy/LangChain/Dropbox/K16/PyWork/.venv/lib/python3.12/site-packages/langchain_core/utils/formatting.py:48, in StrictFormatter.vformat(self, format_string, args, kwargs)
#      43     msg = (
#      44         "No arguments should be provided, "
#      45         "everything should be passed as keyword arguments."
#      46     )
#      47     raise ValueError(msg)
# ---> 48 return super().vformat(format_string, args, kwargs)
#
# File ~/.pyenv/versions/3.12.5/lib/python3.12/string.py:194, in Formatter.vformat(self, format_string, args, kwargs)
#     192 def vformat(self, format_string, args, kwargs):
#     193     used_args = set()
# --> 194     result, _ = self._vformat(format_string, args, kwargs, used_args, 2)
#     195     self.check_unused_args(used_args, args, kwargs)
#     196     return result
#
# File ~/.pyenv/versions/3.12.5/lib/python3.12/string.py:234, in Formatter._vformat(self, format_string, args, kwargs, used_args, recursion_depth, auto_arg_index)
#     230     auto_arg_index = False
#     232 # given the field_name, find the object it references
#     233 #  and the argument it came from
# --> 234 obj, arg_used = self.get_field(field_name, args, kwargs)
#     235 used_args.add(arg_used)
#     237 # do any conversion on the resulting object
#
# File ~/.pyenv/versions/3.12.5/lib/python3.12/string.py:299, in Formatter.get_field(self, field_name, args, kwargs)
#     296 def get_field(self, field_name, args, kwargs):
#     297     first, rest = _string.formatter_field_name_split(field_name)
# --> 299     obj = self.get_value(first, args, kwargs)
#     301     # loop through the rest of the field_name, doing
#     302     #  getattr or getitem as needed
#     303     for is_attr, i in rest:
#
# File ~/.pyenv/versions/3.12.5/lib/python3.12/string.py:256, in Formatter.get_value(self, key, args, kwargs)
#     254     return args[key]
#     255 else:
# --> 256     return kwargs[key]
#
# KeyError: 'country_b'

# %% [markdown]
# ## ChatPromptTemplate

# %%
template = ChatPromptTemplate.from_messages([
    ("system", "You are a geography expert. And your only reply in {language}"),
    ("ai", "안녕, 내 이름은 {name} 이야."),
    ("human", """What is the distance between {country_a} and {country_b}.
          Also, what is your name?"""),    
])

print(type(template))
template
# Out:
# <class 'langchain_core.prompts.chat.ChatPromptTemplate'>
# ChatPromptTemplate(input_variables=['country_a', 'country_b', 'language', 'name'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['language'], input_types={}, partial_variables={}, template='You are a geography expert. And your only reply in {language}'), additional_kwargs={}), AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=['name'], input_types={}, partial_variables={}, template='안녕, 내 이름은 {name} 이야.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['country_a', 'country_b'], input_types={}, partial_variables={}, template='What is the distance between {country_a} and {country_b}.\n          Also, what is your name?'), additional_kwargs={})])

# %%
prompt = template.format_messages(
    language="Korean",
    name="티니핑",
    country_a="USA",
    country_b="South Korea",
)

print(type(prompt))  # List[Message]
prompt
# Out:
# <class 'list'>
# [SystemMessage(content='You are a geography expert. And your only reply in Korean', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='안녕, 내 이름은 티니핑 이야.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#  HumanMessage(content='What is the distance between USA and South Korea.\n          Also, what is your name?', additional_kwargs={}, response_metadata={})]

# %%
chat.invoke(prompt)
# Out:
# AIMessage(content='미국과 한국 사이의 거리는 대략 10,000km입니다. 제 이름은 티니핑입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 35, 'prompt_tokens': 62, 'total_tokens': 97, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DtOZwg7qlLwmh2Y4hfTfuvprehwhP', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019eed22-0adf-77d0-890d-8a5a69b1650e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 62, 'output_tokens': 35, 'total_tokens': 97, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# PromptTemplate 의 이점
# 1. 변수에 대한 검증 가능.
# 2. Prompt 를 저장.  (프롬프트 개발팀 + 애플리케이션 개발팀 분업)

# %% [markdown]
# # OutputParser

# %% [markdown]
# ## Output Parser 란
#
# LLM(대형 언어 모델)에서 생성된 출력을 처리하고 '원하는 형식으로 변환'하는 데 사용되는 유틸리티입니다. 이를 통해 모델이 생성하는 텍스트를 '구조화된 데이터로 변환'하거나, '특정 규칙에 따라 데이터를 추출'할 수 있습니다
#
# 1. 출력 구조화
#     - 모델의 텍스트 응답을 파싱하여 JSON, 딕셔너리, 목록 등과 같은 프로그래밍에서 사용 가능한 구조화된 데이터로 변환합니다
#
# 1. 출력 검증
#     - 모델이 예상치 못한 출력을 반환할 경우 적절한 에러 메시지를 제공하거나 기본값을 반환하도록 처리할 수 있습니다.
#
# 1. 출력 표준화
#     - 언어 모델의 출력이 항상 일관된 형식으로 제공되도록 보장합니다.

# %% [markdown]
# ## BaseOutputParser
# 커스텀 OutputParser 정의

# %%
from langchain_core.output_parsers.base import BaseOutputParser

# %%
class CommaOutputParser(BaseOutputParser):
    # parse() 메소드를 반드시 구현해야 한다.
    #   매개변수: 입력텍스트
    #   리턴: 원하는 형태로 리턴

    # "aaa,bbb,ccc,ddd" => ['aaa', 'bbb', 'ccc', 'ddd'] 로 변환
    def parse(self, text):
        items = text.strip().split(',')
        return list(map(str.strip, items))

# %%
p = CommaOutputParser()

# %%
p.parse("Hello, how,      are    ,    you    ")
# Out:
# ['Hello', 'how', 'are', 'you']

# %%
template = ChatPromptTemplate.from_messages([
    ("system", """
        You are a list generating machine.
        Everything you are asked will be answered with a list of max {max_items}.
        Do NOT reply with anything else.    
    """),
    ("human", "{question}")
])

prompt = template.format_messages(
    max_items=10,
    question="What are the planets?",
)

result = chat.invoke(prompt)
result
# Out:
# AIMessage(content='1. Mercury\n2. Venus\n3. Earth\n4. Mars\n5. Jupiter\n6. Saturn\n7. Uranus\n8. Neptune', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 51, 'total_tokens': 83, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DtOpjaA5g2TFTbgEBxhXYei6PZtBL', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019eed30-f98d-78f3-b4d8-bba7ea7e7885-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 51, 'output_tokens': 32, 'total_tokens': 83, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
print(result.content)
# Out:
# 1. Mercury
# 2. Venus
# 3. Earth
# 4. Mars
# 5. Jupiter
# 6. Saturn
# 7. Uranus
# 8. Neptune

# %%
template = ChatPromptTemplate.from_messages([
    ("system", """
        You are a list generating machine.
        Everything you are asked will be answered with a comma separated list of max {max_items}.
        Do NOT reply with anything else.    
    """),
    ("human", "{question}")
])

prompt = template.format_messages(
    max_items=10,
    question="What are the planets?",
)

result = chat.invoke(prompt)
print(type(result))
result
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# AIMessage(content='Mercury, Venus, Earth, Mars, Jupiter, Saturn, Uranus, Neptune', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 53, 'total_tokens': 70, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DtOrnTnAruZpwUu5bK8UL9bBet7kT', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019eed32-f032-7be1-b5df-a4d21b78e4eb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 53, 'output_tokens': 17, 'total_tokens': 70, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
result.content
# Out:
# 'Mercury, Venus, Earth, Mars, Jupiter, Saturn, Uranus, Neptune'

# %%
prompt = template.format_messages(
    max_items=10,
    question="What are the colors?",
)

result = chat.invoke(prompt)
print(type(result))
result
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# AIMessage(content='red, blue, green, yellow, orange, purple, pink, black, white, brown', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 53, 'total_tokens': 72, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DtOsu8GKQIi6q4Psx416JwsWYREVM', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019eed33-feed-7ec2-88ba-59c6e52a226a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 53, 'output_tokens': 19, 'total_tokens': 72, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
result.content
# Out:
# 'red, blue, green, yellow, orange, purple, pink, black, white, brown'

# %%
template = ChatPromptTemplate.from_messages([
    ("system", """
        You are a list generating machine.
        Everything you are asked will be answered
        with a comma separated list of max {max_items} in lowercase.
        Do NOT reply with anything else.    
    """),
    ("human", "{question}")
])

prompt = template.format_messages(
    max_items=10,
    question="What are the planets?",
)

result = chat.invoke(prompt)
print(type(result))
print(result)
print(result.content)

# OutputParser 적용
print(p.parse(result.content))
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# content='mercury, venus, earth, mars, jupiter, saturn, uranus, neptune' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 57, 'total_tokens': 76, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DtOvnJ1eDs5JHqz7FtpnU8A0VYyy4', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019eed36-b8c2-7f90-a6b0-016171335eee-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 57, 'output_tokens': 19, 'total_tokens': 76, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# mercury, venus, earth, mars, jupiter, saturn, uranus, neptune
# ['mercury', 'venus', 'earth', 'mars', 'jupiter', 'saturn', 'uranus', 'neptune']

# %%
"""
template -> format -> 모델 invoke -> OutputParser ...

위 단계들이 앞으로 많이 반복되고, 이러한 번거로운 과정을 방지하기 위해
=> chain 등장!

LCEL를 사용하여 chain 생성.
chain을 통해 AI 작업의 pipeline을 정의

"""
None

# %% [markdown]
# # ■ Chain, LCEL
#
# - LCEL (LangChain Expression Language: 랭체인 표현 언어)
#   - LCEL은 LangChain 내에서 복잡한 표현식을 처리하고,
#   - 모델과의 상호작용을 더 강력하고 유연하게 만드는 기능을 제공
#     - 코드양을 많이 줄여줌.
#     - 다양한 template 과 LLM 호출
#     - 서로 다른 응답(response) 를 함께 사용케 함

# %%
# chain 이라는 것은 기본적으로, 모든 요소를 연결해주는(합쳐주는) 역할을 함.
# 합쳐진 요소들은 하나의 chain 으로 실행될겁니다.

# chain 생성!
#  '|' (pipe)연산자 사용.
#  LangChain 의 핵심!

chain = template | chat | p

print(type(chain))  # Runnavle 객체 <- 객체는 호출(invoke) 가능
chain
# Out:
# <class 'langchain_core.runnables.base.RunnableSequence'>
# ChatPromptTemplate(input_variables=['max_items', 'question'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=['max_items'], input_types={}, partial_variables={}, template='\n        You are a list generating machine.\n        Everything you are asked will be answered\n        with a comma separated list of max {max_items} in lowercase.\n        Do NOT reply with anything else.    \n    '), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, template='{question}'), additional_kwargs={})])
# | ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.4.8', 'langchain': '1.3.10', 'langchain-openai': '1.3.2'}}, output_version=None, profile={'name': 'GPT-3.5-turbo', 'release_date': '2023-03-01', 'last_updated': '2023-11-06', 'open_weights': False, 'max_input_tokens': 16385, 'max_output_tokens': 4096, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': False, 'structured_output': False, 'attachment': False, 'temperature': True, 'image_url_inputs': False, 'pdf_inputs': False, 'pdf_tool_message': False, 'image_tool_message': False, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x11c8ea390>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x11cbe36b0>, root_client=<openai.OpenAI object at 0x11a3a1bb0>, root_async_client=<openai.AsyncOpenAI object at 0x11b2fd550>, temperature=0.1, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_proxy=None, stream_usage=True, stream_chunk_timeout=120.0)
# | CommaOutputParser()

# %%
# chain.invoke()  # input <- dict 로 제공되어야 함
# chain.invoke({})  # KeyError
chain.invoke({
    # chain 의 첫번째 요소의 입력값들
    "max_items": 5,
    "question": "What are the Pokemons?",
})

# chain.invoke() 리턴값은? -> chain의 마지막 요소의 결과값
# Out:
# ['pikachu', 'charmander', 'bulbasaur', 'squirtle', 'jigglypuff']

# %%
"""
↑ Chain 을 사용해 꽤나 간결한 코드로 작동된다!

chain = template | chat | CommaOutputParser()
chain.invoke({...})
사실 랭체인은 내부에서
  .format_message() 호출 -> prompt 완성
  -> chat.invoke() 호출 -> AIMessage 리턴
  -> parse() 호출한다

이러한 일련의 작업을 chain.invoke() 호출 단한번으로 끝낸다.

이러한 chain 구문으로 정말 다양한 작업의 흐름들을 수행할수 있다.

"""
None

# %%
chain.invoke({
    "max_items": 30,
    "question": "What are the Harry Potter Spells?",
})
# Out:
# ['accio',
#  'alohomora',
#  'lumos',
#  'expelliarmus',
#  'expecto patronum',
#  'wingardium leviosa',
#  'stupefy',
#  'imperio',
#  'crucio',
#  'avada kedavra']

# %%
"""
chain 끼리도 결합할수 도 있다.

[예시]
chain_one = template | chat | CommaOutputParser()
chain_two = template_2 | chat | OutputParser2()

all = chain_one | chain_two | OutputParser3()
  ↑ chain_one 의 출력을 chain_two 의 입력값으로 사용 가능.
"""
None

# %% [markdown]
# # Chaining Chains

# %%
# 첫번째 chain
#   특정 요리에 대한 recipe 를 제공해주는 chef chain

# 두번째 chain
#    요리의 recipe를 받아서 채식주의자용 recipe 로 변환해주는 veg_chef chain

# 최종 chain 
#  위 두개의 chain 을 연결한 chain

# %%
# 첫번째 chain
chef_prompt = ChatPromptTemplate.from_messages([
    ("system", """
      You are a world-class international chef.
      You create easy to follow recipes for any type of cuisines
      with easy to find ingredients.
    """),
    ("human", """
        I want to cook {cuisine} food.
    """),
])

chef_chain = chef_prompt | chat

# %%
print(chef_chain.invoke({'cuisine': 'Korean'}).content)
# Out:
# Great choice! Korean cuisine is delicious and full of flavor. Let's make a popular Korean dish called Bibimbap. It's a mixed rice dish with an assortment of vegetables, meat, and a spicy sauce. Here's a simple recipe for you to try at home:
#
# Ingredients:
# - 1 cup of cooked white rice
# - 1 carrot, julienned
# - 1 zucchini, julienned
# - 1 cup of bean sprouts
# - 1 cup of spinach
# - 4 shiitake mushrooms, sliced
# - 1/2 pound of beef (you can use ribeye or sirloin), thinly sliced
# - 4 eggs
# - Sesame oil
# - Soy sauce
# - Gochujang (Korean red chili paste)
# - Sesame seeds
# - Salt
# - Vegetable oil
#
# Instructions:
# 1. Cook the white rice according to package instructions and set aside.
# 2. In a hot pan, add a little vegetable oil and stir-fry the beef slices until cooked. Season with a little soy sauce and sesame oil. Set aside.
# 3. In the same pan, stir-fry the carrot and zucchini with a little salt until they are cooked but still slightly crunchy. Set aside.
# 4. Blanch the bean sprouts and spinach in boiling water for a few minutes, then drain and squeeze out excess water. Season with a little salt and sesame oil.
# 5. In a separate pan, sauté the shiitake mushrooms with a little salt until cooked. Set aside.
# 6. Fry the eggs sunny side up or however you prefer.
# 7. To assemble the bibimbap, place a serving of rice in a bowl. Arrange the cooked vegetables, beef, and fried egg on top of the rice.
# 8. Mix together 1 tablespoon of gochujang, 1 teaspoon of sesame oil, and a splash of soy sauce to make the bibimbap sauce. Drizzle the sauce over the ingredients.
# 9. Sprinkle with sesame seeds and serve hot.
#
# Enjoy your homemade Bibimbap! Feel free to customize the ingredients to your liking and add more vegetables or protein if desired.

# %%
# 두번째 chain

veg_chef_prompt = ChatPromptTemplate.from_messages([
    ("system", """
      You are a vegetarian chef specialized on
      making traditional recipies vegetarian.
      You find alternative ingredients and explain their preparation.
      You don't radically modify the recipe.
      If there is no alternative for a food just say
      you don't know how to replace it.    
    """),
    ("human", "{recipe}"),
])

veg_chain = veg_chef_prompt | chat

# %%
# 최종 chain

# final_chain = chef_chain | veg_chain <- 이번 예제에서 이리 해도 동작하긴 하지만 권장하지 않음.

# chef_chain 의 output이 veg_chain {recipe} 입력값으로 전달되게 하기.
final_chain = {"recipe": chef_chain} | veg_chain

result = final_chain.invoke({"cuisine": "indian"})

result
# Out:
# AIMessage(content="For a vegetarian version of Chicken Tikka Masala, we can replace the chicken with a suitable alternative like paneer or tofu. Here's how you can adapt the recipe:\n\nIngredients:\n- 1 lb paneer or extra-firm tofu, cut into bite-sized pieces\n- 1 cup plain yogurt (you can use plant-based yogurt for a vegan version)\n- 2 tablespoons lemon juice\n- 2 tablespoons vegetable oil\n- 2 tablespoons garam masala\n- 1 tablespoon ground cumin\n- 1 tablespoon paprika\n- 1 tablespoon minced garlic\n- 1 tablespoon minced ginger\n- 1 teaspoon turmeric\n- 1 teaspoon salt\n- 1 can (14 oz) tomato sauce\n- 1 cup heavy cream (you can use coconut cream for a vegan version)\n- Fresh cilantro, for garnish\n- Cooked rice or naan, for serving\n\nInstructions:\n1. Follow the same marinating process as the original recipe, but instead of chicken, marinate the paneer or tofu in the yogurt and spice mixture. Refrigerate for at least 1 hour.\n\n2. Preheat the oven to 400°F (200°C). Thread the marinated paneer or tofu onto skewers and bake for 20-25 minutes, or until heated through.\n\n3. In a large skillet, follow the same steps for preparing the sauce as in the original recipe. Once the sauce is simmering, add the baked paneer or tofu pieces and simmer for another 10 minutes.\n\n4. Serve the Vegetarian Tikka Masala over rice or with naan bread. Garnish with fresh cilantro.\n\nEnjoy your flavorful Vegetarian Tikka Masala! Feel free to adjust the spices to your liking.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 357, 'prompt_tokens': 731, 'total_tokens': 1088, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DtPiaOtVd6lWvrgVF442VFXF7cHi8', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019eed64-e3d3-7241-9983-0ac20b788a06-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 731, 'output_tokens': 357, 'total_tokens': 1088, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
print(result.content)
# Out:
# For a vegetarian version of Chicken Tikka Masala, we can replace the chicken with a suitable alternative like paneer or tofu. Here's how you can adapt the recipe:
#
# Ingredients:
# - 1 lb paneer or extra-firm tofu, cut into bite-sized pieces
# - 1 cup plain yogurt (you can use plant-based yogurt for a vegan version)
# - 2 tablespoons lemon juice
# - 2 tablespoons vegetable oil
# - 2 tablespoons garam masala
# - 1 tablespoon ground cumin
# - 1 tablespoon paprika
# - 1 tablespoon minced garlic
# - 1 tablespoon minced ginger
# - 1 teaspoon turmeric
# - 1 teaspoon salt
# - 1 can (14 oz) tomato sauce
# - 1 cup heavy cream (you can use coconut cream for a vegan version)
# - Fresh cilantro, for garnish
# - Cooked rice or naan, for serving
#
# Instructions:
# 1. Follow the same marinating process as the original recipe, but instead of chicken, marinate the paneer or tofu in the yogurt and spice mixture. Refrigerate for at least 1 hour.
#
# 2. Preheat the oven to 400°F (200°C). Thread the marinated paneer or tofu onto skewers and bake for 20-25 minutes, or until heated through.
#
# 3. In a large skillet, follow the same steps for preparing the sauce as in the original recipe. Once the sauce is simmering, add the baked paneer or tofu pieces and simmer for another 10 minutes.
#
# 4. Serve the Vegetarian Tikka Masala over rice or with naan bread. Garnish with fresh cilantro.
#
# Enjoy your flavorful Vegetarian Tikka Masala! Feel free to adjust the spices to your liking.

# %% [markdown]
# # streaming= 과 callbacks

# %%
# ↑ 전부 실행 완료 될때까지 기다리는게 지루하다.
#   어떻게 진행되는지도 궁금하다.
#   진행되는 과정을 실시간으로 출력 할수 있다!

# Chat model 의 streaming=True
#  streaming 은 LLM model 의 응답(resposne) 이 생성되는 것을
#    실시간으로(?) 보게 해줌.

# callbacks=[StreamingStdOutCallbackHandler()]
#    볼수 있는 문자(토큰)가 생길 때마다 print 해준다.

# callbacks 는 다양한 'event' 감지도 가능
#    LLM 이 작업을 시작했다거나, 끝냈다거나.
#    문자를 생성했다거나, 에러가 발생하거나..

# %%
from langchain_core.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# %%
chat = ChatOpenAI(
    temperature=0.1,
    streaming=True,
    callbacks=[StreamingStdOutCallbackHandler()],
)

# %%
chef_chain = chef_prompt | chat
veg_chain = veg_chef_prompt | chat
final_chain = {"recipe": chef_chain} | veg_chain

result = final_chain.invoke({
    "cuisine": "french"
})

print("\n✅", result.content)
# Out:
# Great choice! French cuisine is known for its delicious flavors and rich dishes. Let's make a classic French dish - Coq au Vin. This dish features chicken cooked in a rich red wine sauce with mushrooms, onions, and bacon. It's a perfect comfort food for a cozy night in. Here's how you can make it:
#
# Ingredients:
# - 1 whole chicken, cut into pieces
# - 4 slices of bacon, chopped
# - 1 onion, chopped
# - 2 cloves of garlic, minced
# - 1 cup of red wine
# - 1 cup of chicken broth
# - 1 tablespoon of tomato paste
# - 1 tablespoon of all-purpose flour
# - 8 ounces of mushrooms, sliced
# - 2 tablespoons of butter
# - Salt and pepper to taste
# - Fresh parsley for garnish
#
# Instructions:
# 1. In a large Dutch oven or heavy-bottomed pot, cook the bacon over medium heat until it becomes crispy. Remove the bacon and set it aside, leaving the bacon fat in the pot.
#
# 2. Season the chicken pieces with salt and pepper, then brown them in the pot with the bacon fat until they are golden on all sides. Remove the chicken and set it aside.
#
# 3. In the same pot, add the chopped onion and garlic. Cook until the onion is translucent.
#
# 4. Sprinkle the flour over the onions and garlic, stirring to combine. This will help thicken the sauce.
#
# 5. Pour in the red wine and chicken broth, stirring to combine. Add the tomato paste and return the chicken and bacon to the pot. Bring the mixture to a simmer.
#
# 6. Cover the pot and let it simmer for about 45 minutes to 1 hour, or until the chicken is cooked through and tender.
#
# 7. In a separate pan, melt the butter and sauté the mushrooms until they are golden brown.
#
# 8. Add the mushrooms to the pot with the chicken and sauce, stirring to combine. Let it simmer for an additional 10-15 minutes to allow the flavors to meld together.
#
# 9. Taste and adjust the seasoning with salt and pepper as needed.
#
# 10. Serve the Coq au Vin hot, garnished with fresh parsley. This dish pairs well with crusty bread, mashed potatoes, or over a bed of egg noodles.
#
# Enjoy your homemade French Coq au Vin! Bon appétit!For a vegetarian version of Coq au Vin, we can replace the chicken with a plant-based alternative like seitan, tempeh, or tofu. These options can provide a similar texture and absorb the flavors of the dish well. Here's how you can adapt the recipe:
#
# Ingredients:
# - 1 package of seitan, tempeh, or tofu, cut into pieces
# - 4 slices of vegetarian bacon, chopped (look for plant-based bacon alternatives)
# - 1 onion, chopped
# - 2 cloves of garlic, minced
# - 1 cup of red wine
# - 1 cup of vegetable broth
# - 1 tablespoon of tomato paste
# - 1 tablespoon of all-purpose flour
# - 8 ounces of mushrooms, sliced
# - 2 tablespoons of butter or olive oil
# - Salt and pepper to taste
# - Fresh parsley for garnish
#
# Instructions:
# 1. In a large Dutch oven or heavy-bottomed pot, cook the vegetarian bacon over medium heat until it becomes crispy. Remove the bacon and set it aside, leaving the fat in the pot.
#
# 2. Add the seitan, tempeh, or tofu to the pot and brown them in the bacon fat until they are golden on all sides. Remove and set aside.
#
# 3. In the same pot, add the chopped onion and garlic. Cook until the onion is translucent.
#
# 4. Sprinkle the flour over the onions and garlic, stirring to combine.
#
# 5. Pour in the red wine and vegetable broth, stirring to combine. Add the tomato paste and return the seitan, tempeh, or tofu to the pot. Bring the mixture to a simmer.
#
# 6. Cover the pot and let it simmer for about 45 minutes to 1 hour, allowing the flavors to develop.
#
# 7. In a separate pan, melt the butter or heat the olive oil and sauté the mushrooms until they are golden brown.
#
# 8. Add the mushrooms to the pot with the seitan, tempeh, or tofu and sauce, stirring to combine. Let it simmer for an additional 10-15 minutes.
#
# 9. Taste and adjust the seasoning with salt and pepper as needed.
#
# 10. Serve the vegetarian Coq au Vin hot, garnished with fresh parsley. Enjoy this meat-free twist on a classic French dish!
#
# Remember to choose vegetarian bacon and check the wine for vegetarian or vegan certification if needed. This vegetarian Coq au Vin pairs well with the suggested sides like crusty bread, mashed potatoes, or egg noodles. Bon appétit!
# ✅ For a vegetarian version of Coq au Vin, we can replace the chicken with a plant-based alternative like seitan, tempeh, or tofu. These options can provide a similar texture and absorb the flavors of the dish well. Here's how you can adapt the recipe:
#
# Ingredients:
# - 1 package of seitan, tempeh, or tofu, cut into pieces
# - 4 slices of vegetarian bacon, chopped (look for plant-based bacon alternatives)
# - 1 onion, chopped
# - 2 cloves of garlic, minced
# - 1 cup of red wine
# - 1 cup of vegetable broth
# - 1 tablespoon of tomato paste
# - 1 tablespoon of all-purpose flour
# - 8 ounces of mushrooms, sliced
# - 2 tablespoons of butter or olive oil
# - Salt and pepper to taste
# - Fresh parsley for garnish
#
# Instructions:
# 1. In a large Dutch oven or heavy-bottomed pot, cook the vegetarian bacon over medium heat until it becomes crispy. Remove the bacon and set it aside, leaving the fat in the pot.
#
# 2. Add the seitan, tempeh, or tofu to the pot and brown them in the bacon fat until they are golden on all sides. Remove and set aside.
#
# 3. In the same pot, add the chopped onion and garlic. Cook until the onion is translucent.
#
# 4. Sprinkle the flour over the onions and garlic, stirring to combine.
#
# 5. Pour in the red wine and vegetable broth, stirring to combine. Add the tomato paste and return the seitan, tempeh, or tofu to the pot. Bring the mixture to a simmer.
#
# 6. Cover the pot and let it simmer for about 45 minutes to 1 hour, allowing the flavors to develop.
#
# 7. In a separate pan, melt the butter or heat the olive oil and sauté the mushrooms until they are golden brown.
#
# 8. Add the mushrooms to the pot with the seitan, tempeh, or tofu and sauce, stirring to combine. Let it simmer for an additional 10-15 minutes.
#
# 9. Taste and adjust the seasoning with salt and pepper as needed.
#
# 10. Serve the vegetarian Coq au Vin hot, garnished with fresh parsley. Enjoy this meat-free twist on a classic French dish!
#
# Remember to choose vegetarian bacon and check the wine for vegetarian or vegan certification if needed. This vegetarian Coq au Vin pairs well with the suggested sides like crusty bread, mashed potatoes, or egg noodles. Bon appétit!
